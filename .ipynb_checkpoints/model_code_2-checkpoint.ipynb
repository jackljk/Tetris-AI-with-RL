# %%
from Custom_Tetris_Env.tetris import TetrisEnv
from Custom_Tetris_Env.jp import JoypadSpace
from Custom_Tetris_Env.actions import MOVEMENT
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold, CheckpointCallback
from stable_baselines3.common.monitor import Monitor


# Separate evaluation env
eval_env = TetrisEnv(reward_lines=True, reward_score=True, penalize_height=True)
eval_env = JoypadSpace(eval_env, MOVEMENT)
# Stop training when the model reaches the reward threshold
callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback_stop = EvalCallback(eval_env, callback_on_new_best=callback_on_best, verbose=1)

eval_callback_save = EvalCallback(eval_env, best_model_save_path="./logs/",
                             log_path="./logs/", eval_freq=500,
                             deterministic=True, render=False)
checkpoint = CheckpointCallback(save_freq=50000, save_path="./logs/",
                                name_prefix="dqn_tetris")




env = TetrisEnv(reward_lines=True, reward_score=True, penalize_height=True)
env = JoypadSpace(env, MOVEMENT)
env = Monitor(env)

model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./tetris_tensorboard/")
# Out:
# /Users/houkinwan/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/9g/btnfbnzs5s98j60gmhcn4fnh0000gn/T/ipykernel_2617/3283299319.py in <module>
#      27 env = Monitor(env)
#      28
# ---> 29 model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./tetris_tensorboard/")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py in __init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     102         _init_setup_model: bool = True,
#     103     ) -> None:
# --> 104         super().__init__(
#     105             policy,
#     106             env,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py in __init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#     108         supported_action_spaces: Optional[Tuple[Type[spaces.Space], ...]] = None,
#     109     ):
# --> 110         super().__init__(
#     111             policy=policy,
#     112             env=env,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/base_class.py in __init__(self, policy, env, learning_rate, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     178
#     179             if supported_action_spaces is not None:
# --> 180                 assert isinstance(self.action_space, supported_action_spaces), (
#     181                     f"The algorithm only supports {supported_action_spaces} as action spaces "
#     182                     f"but {self.action_space} was provided"
#
# AssertionError: The algorithm only supports (<class 'gymnasium.spaces.discrete.Discrete'>,) as action spaces but Discrete(12) was provided

# %%
# Train the agent
model.learn(total_timesteps=int(1e5), callback=checkpoint)
# Out:
# Logging to ./tetris_tensorboard/DQN_8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Train the agent
# ----> 2 model.learn(total_timesteps=int(1e5), callback=checkpoint)
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:239, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     226 def learn(
#     227     self,
#     228     total_timesteps: int,
#    (...)
#     236     reset_num_timesteps: bool = True,
#     237 ) -> OffPolicyAlgorithm:
# --> 239     return super(DQN, self).learn(
#     240         total_timesteps=total_timesteps,
#     241         callback=callback,
#     242         log_interval=log_interval,
#     243         eval_env=eval_env,
#     244         eval_freq=eval_freq,
#     245         n_eval_episodes=n_eval_episodes,
#     246         tb_log_name=tb_log_name,
#     247         eval_log_path=eval_log_path,
#     248         reset_num_timesteps=reset_num_timesteps,
#     249     )
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:352, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     349 callback.on_training_start(locals(), globals())
#     351 while self.num_timesteps < total_timesteps:
# --> 352     rollout = self.collect_rollouts(
#     353         self.env,
#     354         train_freq=self.train_freq,
#     355         action_noise=self.action_noise,
#     356         callback=callback,
#     357         learning_starts=self.learning_starts,
#     358         replay_buffer=self.replay_buffer,
#     359         log_interval=log_interval,
#     360     )
#     362     if rollout.continue_training is False:
#     363         break
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:566, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     563 action, buffer_action = self._sample_action(learning_starts, action_noise)
#     565 # Rescale and perform action
# --> 566 new_obs, reward, done, infos = env.step(action)
#     568 self.num_timesteps += 1
#     569 episode_timesteps += 1
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# File ~/Library/CloudStorage/GoogleDrive-limjackailjk@gmail.com/Other computers/My Laptop/UCSD/CSE/CSE151B/Final Project/Tetris-AI-with-RL/Custom_Tetris_Env/jp.py:102, in JoypadSpace.step(self, action)
#      99     return combined_array
#     101 action = int(action)
# --> 102 state, reward, done, info = self.env.step(self._action_map[action])
#     104 # Catch exception if current_piece is none which can happen at the start of the game
#     105 try:
#
# File ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/nes_py/nes_env.py:300, in NESEnv.step(self, action)
#     298 self.controllers[0][:] = action
#     299 # pass the action to the emulator as an unsigned byte
# --> 300 _LIB.Step(self._env)
#     301 # get the reward for this step
#     302 reward = float(self._get_reward())
#
# KeyboardInterrupt:

# %%
env = TetrisEnv()
env = JoypadSpace(env, MOVEMENT)

# load checkpoint
model = DQN.load("logs/dqn_model_1000000_steps.zip", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# continue training
model.learn(total_timesteps=int(1e6), callback=checkpoint_callback)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -19.8    |
# |    exploration rate | 0.699    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 640      |
# |    time_elapsed     | 49       |
# |    total timesteps  | 31720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.78e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.408    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 623      |
# |    time_elapsed     | 99       |
# |    total timesteps  | 62272    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.53e-05 |
# |    n_updates        | 240566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.15e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.185    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 602      |
# |    time_elapsed     | 142      |
# |    total timesteps  | 85765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.68e-05 |
# |    n_updates        | 246440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.58e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 594      |
# |    time_elapsed     | 177      |
# |    total timesteps  | 105234   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91e-05 |
# |    n_updates        | 251307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.47e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 586      |
# |    time_elapsed     | 220      |
# |    total timesteps  | 129479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.17e-05 |
# |    n_updates        | 257368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.11e+03 |
# |    ep_rew_mean      | -19.8    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 583      |
# |    time_elapsed     | 251      |
# |    total timesteps  | 146705   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000224 |
# |    n_updates        | 261675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.2e+03  |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 577      |
# |    time_elapsed     | 300      |
# |    total timesteps  | 173666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 268415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.35e+03 |
# |    ep_rew_mean      | -19.8    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 574      |
# |    time_elapsed     | 353      |
# |    total timesteps  | 203086   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97e-05 |
# |    n_updates        | 275770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.38e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 571      |
# |    time_elapsed     | 401      |
# |    total timesteps  | 229738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92e-05 |
# |    n_updates        | 282433   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.7e+03  |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 569      |
# |    time_elapsed     | 470      |
# |    total timesteps  | 267958   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.67e-05 |
# |    n_updates        | 291988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.79e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 568      |
# |    time_elapsed     | 525      |
# |    total timesteps  | 298595   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.99e-05 |
# |    n_updates        | 299647   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.77e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 567      |
# |    time_elapsed     | 572      |
# |    total timesteps  | 324961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.05e-05 |
# |    n_updates        | 306239   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.71e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 566      |
# |    time_elapsed     | 615      |
# |    total timesteps  | 348908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8e-05  |
# |    n_updates        | 312225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.79e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 565      |
# |    time_elapsed     | 672      |
# |    total timesteps  | 380444   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.93e-05 |
# |    n_updates        | 320109   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.79e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 564      |
# |    time_elapsed     | 721      |
# |    total timesteps  | 407271   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.1e-05  |
# |    n_updates        | 326816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.92e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 564      |
# |    time_elapsed     | 785      |
# |    total timesteps  | 443143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0849   |
# |    n_updates        | 335784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.02e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 564      |
# |    time_elapsed     | 846      |
# |    total timesteps  | 477622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.87e-05 |
# |    n_updates        | 344404   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.03e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 564      |
# |    time_elapsed     | 896      |
# |    total timesteps  | 506336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000195 |
# |    n_updates        | 351582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.04e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 570      |
# |    time_elapsed     | 937      |
# |    total timesteps  | 534732   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.75e-05 |
# |    n_updates        | 358681   |
# ----------------------------------
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 7, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 49, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 49, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 49, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 49, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 49, 'next_piece': 'Ih', 'statistics': {'T': 3, 'J': 2, 'Z': 0, 'O': 2, 'S': 0, 'L': 1, 'I': 1}, 'board_height': 12}
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.15e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 578      |
# |    time_elapsed     | 987      |
# |    total timesteps  | 571604   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.89e-05 |
# |    n_updates        | 367899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.26e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 587      |
# |    time_elapsed     | 1038     |
# |    total timesteps  | 609719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.79e-05 |
# |    n_updates        | 377428   |
# ----------------------------------
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 0, 'score': 12, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 52, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 52, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 52, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 52, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# Error:  {'current_piece': None, 'number_of_lines': 1, 'score': 52, 'next_piece': 'Ld', 'statistics': {'T': 2, 'J': 3, 'Z': 3, 'O': 3, 'S': 1, 'L': 1, 'I': 4}, 'board_height': 16}
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.42e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 594      |
# |    time_elapsed     | 1099     |
# |    total timesteps  | 653280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03e-05 |
# |    n_updates        | 388318   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.48e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 600      |
# |    time_elapsed     | 1146     |
# |    total timesteps  | 688060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.26e-05 |
# |    n_updates        | 397013   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.5e+03  |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 605      |
# |    time_elapsed     | 1189     |
# |    total timesteps  | 719981   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07e-05 |
# |    n_updates        | 404994   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.53e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 609      |
# |    time_elapsed     | 1235     |
# |    total timesteps  | 753187   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 413295   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.58e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 615      |
# |    time_elapsed     | 1284     |
# |    total timesteps  | 789892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.27e-05 |
# |    n_updates        | 422471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.58e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 618      |
# |    time_elapsed     | 1325     |
# |    total timesteps  | 820620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e-05 |
# |    n_updates        | 430153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.65e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 622      |
# |    time_elapsed     | 1365     |
# |    total timesteps  | 850331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73e-05 |
# |    n_updates        | 437581   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.76e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 626      |
# |    time_elapsed     | 1407     |
# |    total timesteps  | 881535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.65e-05 |
# |    n_updates        | 445382   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.76e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 628      |
# |    time_elapsed     | 1440     |
# |    total timesteps  | 905390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.05e-05 |
# |    n_updates        | 451346   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 631      |
# |    time_elapsed     | 1488     |
# |    total timesteps  | 939950   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.82e-05 |
# |    n_updates        | 459986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.02e+03 |
# |    ep_rew_mean      | -19.9    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 634      |
# |    time_elapsed     | 1537     |
# |    total timesteps  | 975566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.39e-05 |
# |    n_updates        | 468890   |
# ----------------------------------

# %%
done = False
obs = env.reset()


while not done:
    action, _states = model.predict(obs)
    obs, reward, done, info = env.step(action)
    env.render()

# %%
env.close()
